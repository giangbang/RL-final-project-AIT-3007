# %%
# %cd /kaggle/working
# %rm -rf BTL-AIT-3007
# !git clone -b manh https://github.com/BTL-RL-Nhom19/BTL-AIT-3007.git
# %cd BTL-AIT-3007
# Out:
# /kaggle/working
# Cloning into 'BTL-AIT-3007'...
# remote: Enumerating objects: 579, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 579 (delta 46), reused 75 (delta 31), pack-reused 482 (from 1)
# Receiving objects: 100% (579/579), 18.77 MiB | 19.34 MiB/s, done.
# Resolving deltas: 100% (350/350), done.
# /kaggle/working/BTL-AIT-3007

# %%
# %pip install -r requirements.txt -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 522.8/522.8 kB 10.8 MB/s eta 0:00:0000:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python eval.py
# Out:
# ...
# Eval with random policy
# /usr/local/lib/python3.10/dist-packages/pettingzoo/utils/wrappers/base.py:72: UserWarning: The `action_spaces` dictionary is deprecated. Use the `action_space` function instead.
#   warnings.warn(
# 100%|███████████████████████████████████████████| 30/30 [01:59<00:00,  3.99s/it]
# {'winrate_red': 0.0, 'winrate_blue': 1.0, 'average_rewards_red': -2.001730522522971, 'average_rewards_blue': 4.800555534786909}
# ...
# Eval with trained policy
# 100%|███████████████████████████████████████████| 30/30 [02:03<00:00,  4.10s/it]
# {'winrate_red': 0.0, 'winrate_blue': 1.0, 'average_rewards_red': 0.02844855900961185, 'average_rewards_blue': 4.85847734290179}
# ...
# Eval with final trained policy
# 100%|███████████████████████████████████████████| 30/30 [02:24<00:00,  4.82s/it]
# {'winrate_red': 0.0, 'winrate_blue': 1.0, 'average_rewards_red': 1.1956954594153468, 'average_rewards_blue': 4.88117076254147}
# ...
